# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 100)

# %%
hp = pd.read_csv("data/house_pricing.csv")

# %%
columns1 = hp[["LotArea", "SalePrice"]]

# %%
data1 = columns1[columns1.LotArea<20000][columns1.SalePrice<500000]
# Out:
# <ipython-input-70-e6af10c83df2>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = la[la.LotArea<20000][la.SalePrice<500000]

# %%
plt1 = data1.plot.scatter(x="LotArea", y="SalePrice")

# %%
columns2 = hp[["LotFrontage", "LotArea"]]

# %%
data2 = columns2[columns2.LotFrontage<200][columns2.LotArea<100000]
# Out:
# <ipython-input-73-6825356fbd36>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data2 = columns2[columns2.LotFrontage<200][columns2.LotArea<100000]

# %%
plt2 = data2.plot.scatter(x="LotFrontage", y="LotArea")
